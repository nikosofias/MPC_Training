# %% [markdown]
# # MPC with CaSaDi

# %%
import data_generator as dg
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
d_full = dg.import_disturbance()
d_full.shape
# Out:
# disturbance vector loaded
# peek into d_full (First 5 elements) :
# [[10.          0.          1.        ]
#  [10.          0.          1.        ]
#  [10.          0.          1.        ]
#  [ 8.33333333  0.          1.        ]
#  [ 6.          0.          1.        ]]
# (145, 3)

# %%
d_full_df = pd.DataFrame(d_full)
d_full_df.columns = ['room_temp','sol_rad','int_gains']
d_full_df.head()
# Out:
#    room_temp  sol_rad  int_gains
# 0  10.000000      0.0        1.0
# 1  10.000000      0.0        1.0
# 2  10.000000      0.0        1.0
# 3   8.333333      0.0        1.0
# 4   6.000000      0.0        1.0

# %%
d_full_df.plot(subplots=True, figsize=(10,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
list_x0 = dg.generate_list_x0()
list_x0.shape # columns 1 is the x0's for Tr and column 2 is for x0's for Ebat
# Out:
# (100, 2)

# %%
plt.plot(list_x0[:,0])

# %%
import pandas as pd

df = pd.read_csv('data/Varying_disturbance_simulation_data10000lines.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#              0              1          2          3          4          5  \
# 0    20.000000       0.000000  -1.006873 -10.434678  -0.776072  -4.460560
# 1    19.012933      33.499117  -3.192114  -4.764093   3.975958  -5.235882
# 2    16.446494    2533.206616   4.624291  14.932219   0.378142  10.865644
# 3    16.975607    1156.614420  24.607852   6.508523   2.161914   5.606276
# 4    17.234923       0.000007  13.500957  -7.364899 -13.865237  16.356354
# ..         ...            ...        ...        ...        ...        ...
# 995  20.000000  187499.999875   8.404799   4.747269  -9.027190   6.699806
# 996  20.000000  184999.999850  -1.885330 -19.071860  -0.690370   5.517240
# 997  20.000000  182499.999825   6.136479  10.985567  -2.481916  12.759420
# 998  20.000000  179999.999800  -4.936543  -1.226002  -7.441585  18.383639
# 999  20.000000  177499.999775  27.189717  22.364539 -10.561954  10.119585
#
#              6          7          8           9         10         11  \
# ...

# %%
df.iloc[:, -1].plot(figsize=(20, 10), title='Disturbance')
# Out:
# <AxesSubplot:title={'center':'Disturbance'}>
